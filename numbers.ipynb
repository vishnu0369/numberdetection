# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# ...
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
plt.matshow(X_train[0])

# %%
y_train[0]
# Out:
# 5

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
model = keras.Sequential([
    
    layers.Conv2D(30, (3,3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2,2)),
 
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.8695 - accuracy: 0.7429
# Epoch 2/5
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.3490 - accuracy: 0.8964
# Epoch 3/5
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.2971 - accuracy: 0.9124
# Epoch 4/5
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.2632 - accuracy: 0.9226
# Epoch 5/5
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.2357 - accuracy: 0.9305

# %%
y_train[:5]
# Out:
# array([5, 0, 4, 1, 9], dtype=uint8)

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.2285 - accuracy: 0.9310
# [0.22852173447608948, 0.9309999942779541]

# %%
plt.imshow(X_test[7],cmap=plt.cm.binary)

# %%
plt.imshow(X_test[7],cmap="gray")

# %%
predictions = model.predict(np.expand_dims(X_test[7], axis=0))    # Here we used np.expand_dims to make x_test[n] 
                                                                    #to make 3dims because predict expect batch input, not single input

# %%
print (np.argmax(predictions))
# Out:
# 9
